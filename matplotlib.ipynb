# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka2611/MachineLearning/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('matplotlib - data visulaization')
#lineplot
 #plot : 1 image , subplot: 2> images
import numpy as np
from matplotlib import pyplot as plt
x= np.arange(1,12)
y= x*2

plt.plot(x,y, color='g', linestyle=':', linewidth =5)
plt.title('line plot')
plt.xlabel('x------')
plt.ylabel('y-----')
plt.show()
# Out:
# matplotlib - data visulaization

# %%
x= np.arange(1,12)
y2= x*2
y1= x*3

plt.plot(x,y2, color='g', linestyle=':', linewidth =5)

plt.plot(x,y1, color='r', linestyle='-', linewidth =3)
plt.title('line plot')
plt.xlabel('x------')
plt.ylabel('y-----')
plt.grid(True) #show grid in background
plt.show()

# %%
x= np.arange(1,12)
y2= x*2
y1= x*3
#subplot(nrows, ncols, index, **kwargs)  subplot(pos, **kwargs)  subplot(ax)  
   
plt.subplot(1,2,1) #row, column, index of subplot
plt.plot(x,y2, color='g', linestyle=':', linewidth =5)
plt.subplot(1,2,2)
plt.plot(x,y1, color='r', linestyle='-', linewidth =3)
plt.title('line plot')
plt.xlabel('x------')
plt.ylabel('y-----')
plt.grid(True) #show grid in background
plt.show()

# %%
print('barplot')
student={"bob": 70, "mam": 20, "sam": 30}

names= list(student.keys())
print(names)
values= list(student.values())
plt.bar(names,values)
plt.title('bar plot')
plt.xlabel('x------')
plt.ylabel('y-----')
plt.grid(True)
plt.show()
plt.barh(names,values, color='g')
plt.title('bar plot')
plt.xlabel('x------')
plt.ylabel('y-----')
plt.grid(True)
plt.show()
# Out:
# barplot
# ['bob', 'mam', 'sam']

# %%
print('scatter plot with subplots')
x= [22,35,13,27]
y =[2,5,3,7]
a=[9,8,6,5]
plt.scatter(x,y,color='r',marker='*', s=100)
plt.scatter(x,a,color='b', s=100)
plt.show()

x1= [22,35,13,27]
y1 =[2,5,3,7]
a1=[9,8,6,5]
plt.subplot(2,1,1)
plt.scatter(x1,y1,color='r',marker='*', s=100)
plt.subplot(2,1,2)
plt.scatter(x1,a1,color='b', s=100)
plt.show()
# Out:
# scatter plot

# %%
print('histogram') #for numerical values where as bar are vo categorial values
import pandas as pd
data=[1,3,5,7,3,4,7,5,8,9,0,0,3,6,4,1,3]
plt.hist(data, color='y', bins=70)
plt.show()

iris=pd.read_csv('iris.csv')
print(iris.head())
plt.hist(iris['petal_width'], color='r', bins= 50)
plt.show()
# Out:
# histogram
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print("boxplot- percentile base fi  number summary , violin plot ~ to box plot")
one=[1,2,5]
to= [4,2,3]
three=[8,6,5]
listval= list([one,to,three])
plt.subplot(1,2,1)
plt.boxplot(listval)
plt.subplot(1,2,2)
plt.violinplot(listval, showmedians=True)
plt.show()
# Out:
# boxplot- percentile base fi  number summary , violin plot ~ to box plot

# %%
print('pie chart')

fruit=['applie', 'mang','banan','orange']
price=[11,34,45,65]
plt.subplot(1,2,1)
plt.pie(price,labels=fruit, autopct='%0.1f%%', colors=['red','green','orange','yellow'])
plt.show()
plt.subplot(1,2,2)
plt.pie(price,labels=fruit, radius =2)
plt.pie([1], colors=['w'], radius=1)
plt.show()
# Out:
# pie chart
